# %% [markdown]
# <a href="https://colab.research.google.com/github/YuliaLeonchik/-/blob/main/%D0%9B%D0%B5%D0%BE%D0%BD%D1%87%D0%B8%D0%BA_%D0%91%D0%98%D0%9A_24_%D0%98%D0%922_%D0%9B%D0%A04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = int(input())
match x:
  case 400:
    print('Неправильный зарос')
  case 401:
    print('Unauthorized')
  case 402:
    print('Payment Required')
  case 403:
    print('Forbidden')
  case 404:
    print('Not Found')
  case 405:
    print('Method Not Allowed')
# Out:
# 401
# Unauthorized

# %%
x = int(input())
y = int(input())
if (x > 0 and y > 0):
  print('1 четверть')
if (x < 0 and y > 0):
  print('2 четверть')
if (x < 0 and y < 0):
  print('3 четверь')
if (x > 0 and y < 0):
  print('4 четверть')
# Out:
# 5
# 5
# 1 четверть

# %%
x = int(input())
if ()
