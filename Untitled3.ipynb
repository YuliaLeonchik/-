# %% [markdown]
# <a href="https://colab.research.google.com/github/YuliaLeonchik/-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input())
m = int(input())
suma = sum(range(n, m + 1))
print(suma)
# Out:
# 2
# 4
# 9

# %%
n = int(input())
m = int(input())
suma = sum(range(n, m +1))
if n == m:
  break
else:
  print(suma)
# Out:
# 2
# 3
#   File "<ipython-input-20-e52894a1bf06>", line 7
#     break
#     ^
# SyntaxError: 'break' outside loop
